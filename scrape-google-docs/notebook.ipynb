# %%
print("no")
# Out:
# no

# %%
import requests
from bs4 import BeautifulSoup
from io import StringIO
import pandas as pd

def parse_google_doc_table_html(url):
    resp = requests.get(url)
    soup = BeautifulSoup(resp.text, 'html.parser')
    
    # Find the first table
    table = StringIO(str(soup.find('table')))  # wrapped in StringIO to prevent warnings
    
    if table:
        dfs = pd.read_html(table, header=0)  # returns list of DFs
        if dfs:
            return dfs[0] # Returns the first table as a pandas DataFrame
    return None

def print_secret_message(url):
    pass

def main():
    # test
    url = 'https://docs.google.com/document/d/e/2PACX-1vTMOmshQe8YvaRXi6gEPKKlsC6UpFJSMAk4mQjLm_u1gmHdVVTaeh7nBNFBRlui0sTZ-snGwZM4DBCT/pub'
    
    # real
    #url = 'https://docs.google.com/document/d/e/2PACX-1vSvM5gDlNvt7npYHhp_XfsJvuntUhq184By5xO_pA4b_gCWeXb6dM6ZxwN8rE6S4ghUsCj2VKR21oEP/pub'
    
    print_secret_message(url)

if __name__ == "__main__":
    main()
# Out:
# hi

# %%
url = 'https://docs.google.com/document/d/e/2PACX-1vTMOmshQe8YvaRXi6gEPKKlsC6UpFJSMAk4mQjLm_u1gmHdVVTaeh7nBNFBRlui0sTZ-snGwZM4DBCT/pub'

df = parse_google_doc_table_html(url)
df.head()
# Out:
#    x-coordinate Character  y-coordinate
# 0             0         █             0
# 1             0         █             1
# 2             0         █             2
# 3             1         ▀             1
# 4             1         ▀             2

# %%
# !pip install html5lib
